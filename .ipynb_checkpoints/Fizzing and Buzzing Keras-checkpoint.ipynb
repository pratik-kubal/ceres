# %% [markdown]
# ## Logic Based FizzBuzz Function [Software 1.0]

# %%
from numpy.random import seed
seed(111)
    
from tensorflow import set_random_seed
set_random_seed(125)

from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.callbacks import EarlyStopping, TensorBoard
from keras.utils import np_utils
import keras
import numpy as np
import pandas as pd
# Out:
# Using TensorFlow backend.

# %%
def fizzbuzz(n):
    
    # Logic Explanation
    # If n / a ; where a is any number greater than 1 has the remainder as 0 which means it is divisible by n. Therefore,
    # in the first condition we check if it is divisible by both 3 and 5, If it isn't then we check if it is divisible
    # by only 3 and if not then try 5. If it is not divisible by either 3 or 5 then we return "Other". All the other return
    # statements work on the FizzBuzz Game.
    if n % 3 == 0 and n % 5 == 0:
        return 'FizzBuzz'
    elif n % 3 == 0:
        return 'Fizz'
    elif n % 5 == 0:
        return 'Buzz'
    else:
        return 'Other'

# %% [markdown]
# ## Create Training and Testing Datasets in CSV Format

# %%
def createInputCSV(start,end,filename):
    
    # Why list in Python?
    # Amongst other data types in Python, List is an example of mutable object. We need a mutable object to
    # modify the data such as to Normalize the data set, also Machine Learning is based on repetative examples
    # if we use a tuple then it wouldn't be possible. Since Data frames use dictionary of lists to write data to csv
    # this is another case where we need them
    inputData   = []
    outputData  = []
    
    # Why do we need training Data?
    # We need training data to teach the model about what answer is expected from it. Example to make it learn what is 
    # a cat we have to show it pictures of cat
    for i in range(start,end):
        inputData.append(i)
        outputData.append(fizzbuzz(i))
    
    # Why Dataframe?
    # Data frames enable us to view multi-column data in two dimensions which is usefull here because one part is the
    # input while the other is the output
    dataset = {}
    dataset["input"]  = inputData
    dataset["label"] = outputData
    
    # Writing to csv
    pd.DataFrame(dataset).to_csv(filename)
    
    print(filename, "Created!")

# %% [markdown]
# ## Processing Input and Label Data

# %%
def processData(dataset):
    
    # Why do we have to process?
    # If we just input the numbers as they are then we won't be able to show patterns in the data. Each input will be 
    # connected to n hidden layers, which is useless. Another case is of dimensionality, a 4 labelled output data cannot
    # be expressed in 1dimensions(viz. Using only 1 input). We need atleast 4 or more than that so that the vectors
    # span all the dimensions
    data   = dataset['input'].values
    labels = dataset['label'].values
    
    processedData  = encodeData(data)
    processedLabel = encodeLabel(labels)
    
    return processedData, processedLabel

# %%
def encodeData(data):
    
    processedData = []
    
    for dataInstance in data:
        
        # Why do we have number 10?
        # Because we are planning to have 10 input Layer neurons/nodes also the max number which we have to train for is
        # 1000 which takes up 10 bits after converting it to binary.
        processedData.append([dataInstance >> d & 1 for d in range(10)])
    
    return np.array(processedData)

# %%
def encodeLabel(labels):
    
    processedLabel = []
    
    for labelInstance in labels:
        if(labelInstance == "FizzBuzz"):
            # Fizzbuzz
            processedLabel.append([3])
        elif(labelInstance == "Fizz"):
            # Fizz
            processedLabel.append([1])
        elif(labelInstance == "Buzz"):
            # Buzz
            processedLabel.append([2])
        else:
            # Other
            processedLabel.append([0])

    return np_utils.to_categorical(np.array(processedLabel),4)

# %% [markdown]
# ## Model Definition

# %%
input_size = 10
drop_out = 0.2
first_dense_layer_nodes  = 256
second_dense_layer_nodes = 128
final_dense_layer_nodes = 4

def get_model():

    
    
    # Why do we need a model?
    # Model is like a black box, we need it basically to teach it how to translate the inputs to required output
    
    # Why use Dense layer and then activation?
    # Dense layer is like a structure. Formally a dense layer implemnts kernel i.e The weight matrix which is used
    # while running it iterations.
    # Activation is a function of input vectors and the kernel. Therefore, we first need kernel ie. The weight matrix
    # or the dense layer before activation
    # https://keras.io/layers/core/
    
    # Why use sequential model with layers?
    # Sequential model allows us to design the network layer by layer. It is enough for simple cases like we have now
    # https://jovianlin.io/keras-models-sequential-vs-functional/
    model = Sequential()
    
    model.add(Dense(first_dense_layer_nodes, input_dim=input_size))
    model.add(Activation('relu'))
    
    model.add(Dense(second_dense_layer_nodes))
    model.add(Activation('relu'))
    
    # Why dropout?
    # Avoids the model being overfitted for the training data such that it fails to generalize for new 
    # incidences.
    model.add(Dropout(drop_out))
    
    model.add(Dense(final_dense_layer_nodes))
    model.add(Activation('softmax'))
    # Why Softmax?
    # Since this is a multi class classification problem, for the last output layer we need to translate the continous signal 
    # into a discrete signal which will give us the classes. The softmax activation converts a vector of arbitary
    # real values into a vector of values in a specific range from which we can get categories.
    # Important thing to note is that the predicted class will belong to only one class, therefore sum of 
    # probabalities sums to one. For Multi label problem we have to use a different activation, perhaps 
    # sigmoid.
    
    model.summary()
    
    # Why use categorical_crossentropy?
    # Here if we have to use crossentropy loss functions we have various choices such as Binary Crossentropy, categorical
    # crossentropy and Sparse Crossentropy. Here we have One-hot Encoded the input therefore we have to use categorical
    # crossentropy.
    # https://jovianlin.io/cat-crossentropy-vs-sparse-cat-crossentropy/
    
    # Commented out to use metrics as categorical_accuracy for categorical data
    #model.compile(optimizer='rmsprop',
    #              loss='categorical_crossentropy',
    #              metrics=['accuracy'])
    #model.compile(loss='categorical_crossentropy', optimizer='rmsprop',metrics=['accuracy'])
    #rmsprop = keras.optimizers.RMSprop(lr=0.01, rho=0.9, epsilon=None, decay=0.0)
    #model.compile(loss='categorical_crossentropy', optimizer=rmsprop,metrics=['accuracy'])
    
    #sgd = keras.optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
    adadelta = keras.optimizers.Adadelta(lr=1.0, rho=0.95, epsilon=None, decay=0)
    
    model.compile(loss='categorical_crossentropy', optimizer=adadelta,metrics=['categorical_accuracy'])
    
    return model

# %% [markdown]
# # <font color='blue'>Creating Training and Testing Datafiles</font>

# %%
# Create datafiles
createInputCSV(101,1001,'training.csv')
createInputCSV(1,101,'testing.csv')
# Out:
# training.csv Created!
# testing.csv Created!

# %% [markdown]
# # <font color='blue'>Creating Model</font>

# %%
model = get_model()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_94 (Dense)             (None, 256)               2816
# _________________________________________________________________
# activation_91 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_95 (Dense)             (None, 128)               32896
# _________________________________________________________________
# activation_92 (Activation)   (None, 128)               0
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_96 (Dense)             (None, 4)                 516
# _________________________________________________________________
# activation_93 (Activation)   (None, 4)                 0
# =================================================================
# Total params: 36,228
# Trainable params: 36,228
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # <font color = blue>Run Model</font>

# %%
validation_data_split = 0.2
num_epochs = 10000
model_batch_size = 128
tb_batch_size = 32
early_patience = 200

# CHANGE TENSORBOARD FOLDER LOCATION AFTER EACH MODEL RUN
tensorboard_cb   = TensorBoard(log_dir='./logs/kerasLogs/default/', batch_size= tb_batch_size, write_graph= True)
earlystopping_cb = EarlyStopping(monitor='val_loss', verbose=1, patience=early_patience, mode='min')
#reduce_LR = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=early_patience, verbose=0, mode='auto', min_delta=0.0001, cooldown=0, min_lr=0)

# Read Dataset
dataset = pd.read_csv('training.csv')

# Process Dataset
processedData, processedLabel = processData(dataset)
history = model.fit(processedData
                    , processedLabel
                    , validation_split=validation_data_split
                    , epochs=num_epochs
                    , batch_size=model_batch_size
                    , callbacks = [tensorboard_cb,earlystopping_cb]
                   )
# Out:
# Train on 720 samples, validate on 180 samples
# Epoch 1/10000
# 720/720 [==============================] - 2s 3ms/step - loss: 1.2698 - categorical_accuracy: 0.4667 - val_loss: 1.1523 - val_categorical_accuracy: 0.5333
# Epoch 2/10000
# 720/720 [==============================] - 0s 85us/step - loss: 1.1612 - categorical_accuracy: 0.5333 - val_loss: 1.1470 - val_categorical_accuracy: 0.5333
# Epoch 3/10000
# 720/720 [==============================] - 0s 102us/step - loss: 1.1510 - categorical_accuracy: 0.5361 - val_loss: 1.1525 - val_categorical_accuracy: 0.5333
# Epoch 4/10000
# 720/720 [==============================] - 0s 88us/step - loss: 1.1489 - categorical_accuracy: 0.5333 - val_loss: 1.1553 - val_categorical_accuracy: 0.5333
# Epoch 5/10000
# 720/720 [==============================] - 0s 104us/step - loss: 1.1468 - categorical_accuracy: 0.5333 - val_loss: 1.1460 - val_categorical_accuracy: 0.5333
# Epoch 6/10000
# 720/720 [==============================] - 0s 80us/step - loss: 1.1398 - categorical_accuracy: 0.5333 - val_loss: 1.1517 - val_categorical_accuracy: 0.5333
# Epoch 7/10000
# 720/720 [==============================] - 0s 65us/step - loss: 1.1444 - categorical_accuracy: 0.5333 - val_loss: 1.1556 - val_categorical_accuracy: 0.5333
# Epoch 8/10000
# 720/720 [==============================] - 0s 62us/step - loss: 1.1388 - categorical_accuracy: 0.5333 - val_loss: 1.1570 - val_categorical_accuracy: 0.5333
# Epoch 9/10000
# 720/720 [==============================] - 0s 69us/step - loss: 1.1409 - categorical_accuracy: 0.5333 - val_loss: 1.1673 - val_categorical_accuracy: 0.5333
# Epoch 10/10000
# 720/720 [==============================] - 0s 78us/step - loss: 1.1405 - categorical_accuracy: 0.5333 - val_loss: 1.1471 - val_categorical_accuracy: 0.5333
# Epoch 11/10000
# 720/720 [==============================] - 0s 79us/step - loss: 1.1420 - categorical_accuracy: 0.5333 - val_loss: 1.1538 - val_categorical_accuracy: 0.5333
# Epoch 12/10000
# 720/720 [==============================] - 0s 77us/step - loss: 1.1301 - categorical_accuracy: 0.5333 - val_loss: 1.1548 - val_categorical_accuracy: 0.5333
# Epoch 13/10000
# 720/720 [==============================] - 0s 83us/step - loss: 1.1333 - categorical_accuracy: 0.5333 - val_loss: 1.1500 - val_categorical_accuracy: 0.5333
# Epoch 14/10000
10000
# 720/720 [==============================] - 0s 70us/step - loss: 0.9905 - categorical_accuracy: 0.5556 - val_loss: 1.1379 - val_categorical_accuracy: 0.5333
# Epoch 51/10000
# 720/720 [==============================] - 0s 71us/step - loss: 0.9752 - categorical_accuracy: 0.5736 - val_loss: 1.1103 - val_categorical_accuracy: 0.5278
# Epoch 52/10000
# 720/720 [==============================] - 0s 66us/step - loss: 0.9656 - categorical_accuracy: 0.5694 - val_loss: 1.1165 - val_categorical_accuracy: 0.5500
# Epoch 53/10000
# 720/720 [==============================] - 0s 72us/step - loss: 0.9567 - categorical_accuracy: 0.5653 - val_loss: 1.1132 - val_categorical_accuracy: 0.5056
# Epoch 54/10000
# 720/720 [==============================] - 0s 76us/step - loss: 0.9484 - categorical_accuracy: 0.5917 - val_loss: 1.1107 - val_categorical_accuracy: 0.5333
# Epoch 55/10000
# 720/720 [==============================] - 0s 71us/step - loss: 0.9400 - categorical_accuracy: 0.5903 - val_loss: 1.0956 - val_categorical_accuracy: 0.5444
# Epoch 56/10000
# 720/720 [==============================] - 0s 72us/step - loss: 0.9237 - categorical_accuracy: 0.5694 - val_loss: 1.1017 - val_categorical_accuracy: 0.5167
# Epoch 57/10000
# 720/720 [==============================] - 0s 78us/step - loss: 0.9125 - categorical_accuracy: 0.5833 - val_loss: 1.1231 - val_categorical_accuracy: 0.4944
# Epoch 58/10000
# 720/720 [==============================] - 0s 64us/step - loss: 0.9318 - categorical_accuracy: 0.5681 - val_loss: 1.1212 - val_categorical_accuracy: 0.4389
# Epoch 59/10000
# 720/720 [==============================] - 0s 74us/step - loss: 0.9181 - categorical_accuracy: 0.6153 - val_loss: 1.0731 - val_categorical_accuracy: 0.5500
# Epoch 60/10000
# 720/720 [==============================] - 0s 66us/step - loss: 0.9002 - categorical_accuracy: 0.5847 - val_loss: 1.1206 - val_categorical_accuracy: 0.5111
# Epoch 61/10000
# 720/720 [==============================] - 0s 63us/step - loss: 0.9234 - categorical_accuracy: 0.5972 - val_loss: 1.0713 - val_categorical_accuracy: 0.5667
# Epoch 62/10000
# 720/720 [==============================] - 0s 68us/step - loss: 0.8720 - categorical_accuracy: 0.6181 - val_loss: 1.1181 - val_categorical_accuracy: 0.4833
# Epoch 63/10000
# 720/720 [==============================] - 0s 57us/step - loss: 0.8822 - categorical_accuracy: 0.6292 - val_loss: 1.0421 - val_categorical_accuracy: 0.5556
# Epoch 64/10000
# 720/720 [==============================] - 0s 123us/step - loss: 0.8529 - categorical_accuracy: 0.6417 - val_loss: 1.0345 - val_categorical_accuracy: 0.5778
# Epoch 65/10000
# 720/720 [==============================] - 0s 74us/step - loss: 0.8409 - categorical_accuracy: 0.6417 - val_loss: 1.0432 - val_categorical_accuracy: 0.5833
# Epoch 66/10000
# 720/720 [==============================] - 0s 74us/step - loss: 0.8228 - categorical_accuracy: 0.6514 - val_loss: 1.1005 - val_categorical_accuracy: 0.4722
# Epoch 67/10000
# 720/720 [==============================] - 0s 63us/step - loss: 0.8805 - categorical_accuracy: 0.6347 - val_loss: 1.1304 - val_categorical_accuracy: 0.5000
# Epoch 68/10000
# 720/720 [==============================] - 0s 64us/step - loss: 0.8596 - categorical_accuracy: 0.6611 - val_loss: 1.0003 - val_categorical_accuracy: 0.6278
# Epoch 69/10000
# 720/720 [==============================] - 0s 89us/step - loss: 0.7845 - categorical_accuracy: 0.7014 - val_loss: 1.0455 - val_categorical_accuracy: 0.5833
# Epoch 70/10000
# 720/720 [==============================] - 0s 71us/step - loss: 0.8636 - categorical_accuracy: 0.6167 - val_loss: 0.9804 - val_categorical_accuracy: 0.6333
# Epoch 71/10000
# 720/720 [==============================] - 0s 100us/step - loss: 0.8404 - categorical_accuracy: 0.6292 - val_loss: 0.9893 - val_categorical_accuracy: 0.5889
# Epoch 72/10000
# 720/720 [==============================] - 0s 70us/step - loss: 0
10000
# 720/720 [==============================] - 0s 71us/step - loss: 0.0034 - categorical_accuracy: 1.0000 - val_loss: 0.3167 - val_categorical_accuracy: 0.9222
# Epoch 434/10000
# 720/720 [==============================] - 0s 91us/step - loss: 0.0044 - categorical_accuracy: 1.0000 - val_loss: 0.4304 - val_categorical_accuracy: 0.8889
# Epoch 435/10000
# 720/720 [==============================] - 0s 58us/step - loss: 0.0032 - categorical_accuracy: 1.0000 - val_loss: 0.3329 - val_categorical_accuracy: 0.9056
# Epoch 436/10000
# 720/720 [==============================] - 0s 72us/step - loss: 0.0038 - categorical_accuracy: 1.0000 - val_loss: 0.3258 - val_categorical_accuracy: 0.9111
# Epoch 437/10000
# 720/720 [==============================] - 0s 68us/step - loss: 0.0033 - categorical_accuracy: 1.0000 - val_loss: 0.3280 - val_categorical_accuracy: 0.9056
# Epoch 438/10000
# 720/720 [==============================] - 0s 51us/step - loss: 0.0029 - categorical_accuracy: 1.0000 - val_loss: 0.3661 - val_categorical_accuracy: 0.9056
# Epoch 439/10000
# 720/720 [==============================] - 0s 93us/step - loss: 0.0034 - categorical_accuracy: 1.0000 - val_loss: 0.3099 - val_categorical_accuracy: 0.9167
# Epoch 440/10000
# 720/720 [==============================] - 0s 96us/step - loss: 0.0027 - categorical_accuracy: 1.0000 - val_loss: 0.3092 - val_categorical_accuracy: 0.9056
# Epoch 441/10000
# 720/720 [==============================] - 0s 114us/step - loss: 0.0029 - categorical_accuracy: 1.0000 - val_loss: 0.2887 - val_categorical_accuracy: 0.9222
# Epoch 442/10000
# 720/720 [==============================] - 0s 96us/step - loss: 0.0024 - categorical_accuracy: 1.0000 - val_loss: 0.3109 - val_categorical_accuracy: 0.9111
# Epoch 443/10000
# 720/720 [==============================] - 0s 85us/step - loss: 0.0028 - categorical_accuracy: 1.0000 - val_loss: 0.3286 - val_categorical_accuracy: 0.9111
# Epoch 444/10000
# 720/720 [==============================] - 0s 72us/step - loss: 0.0040 - categorical_accuracy: 1.0000 - val_loss: 0.2937 - val_categorical_accuracy: 0.9000
# Epoch 445/10000
# 720/720 [==============================] - 0s 65us/step - loss: 0.0028 - categorical_accuracy: 1.0000 - val_loss: 0.3191 - val_categorical_accuracy: 0.9111
# Epoch 446/10000
# 720/720 [==============================] - 0s 62us/step - loss: 0.0037 - categorical_accuracy: 1.0000 - val_loss: 0.3449 - val_categorical_accuracy: 0.9111
# Epoch 447/10000
# 720/720 [==============================] - 0s 71us/step - loss: 0.0027 - categorical_accuracy: 1.0000 - val_loss: 0.3430 - val_categorical_accuracy: 0.9000
# Epoch 448/10000
# 720/720 [==============================] - 0s 61us/step - loss: 0.0025 - categorical_accuracy: 1.0000 - val_loss: 0.3316 - val_categorical_accuracy: 0.9056
# Epoch 449/10000
# 720/720 [==============================] - 0s 82us/step - loss: 0.0033 - categorical_accuracy: 1.0000 - val_loss: 0.3515 - val_categorical_accuracy: 0.9056
# Epoch 450/10000
# 720/720 [==============================] - 0s 95us/step - loss: 0.0029 - categorical_accuracy: 1.0000 - val_loss: 0.3642 - val_categorical_accuracy: 0.9111
# Epoch 451/10000
# 720/720 [==============================] - 0s 82us/step - loss: 0.0024 - categorical_accuracy: 1.0000 - val_loss: 0.3188 - val_categorical_accuracy: 0.9222
# Epoch 452/10000
# 720/720 [==============================] - 0s 74us/step - loss: 0.0051 - categorical_accuracy: 0.9986 - val_loss: 0.4924 - val_categorical_accuracy: 0.8833
# Epoch 453/10000
# 720/720 [==============================] - 0s 69us/step - loss: 0.0074 - categorical_accuracy: 0.9986 - val_loss: 0.3129 - val_categorical_accuracy: 0.9167
# Epoch 454/10000
# 720/720 [==============================] - 0s 75us/step - loss: 0.0022 - categorical_accuracy: 1.0000 - val_loss: 0.3437 - val_categorical_accuracy: 0.9111
# Epoch 455/10000
# 720/720 [==============================] - 0s 92us/step - loss: 0.0029 - categorical_accuracy: 1.0000 - val_loss: 0.2994 - val_categorical_accuracy: 0.9167
# Epoch 456/10000
# 720/720 [==============================] - 0s 100us/step - loss: 0.0023 - categorical_accuracy: 1.0000 - val_loss: 0.3068 - val_categorical_accuracy: 0.9111
# Epoch 457/10000
# 720/720 [==============================] - 0s 85us/step - loss: 0.0024 - categorical_accuracy: 1.0000 - val_loss: 0.3296 - val_categorical_accuracy: 0.9111
# Epoch 458/10000
# 720/720 [==============================] - 0s 97us/step - loss: 0.0026 - categorical_accuracy: 1.0000 - val_loss: 0.3134 - val_categorical_accuracy: 0.9222
# Epoch 459/10000
# 720/720 [==============================] - 0s 80us/step - loss: 0.0021 - categorical_accuracy: 1.0000 - val_loss: 0.3315 - val_categorical_accuracy: 0.9111
# Epoch 460/10000
# 720/720 [==============================] - 0s 105us/step - loss: 0.0027 - categorical_accuracy: 1.0000 - val_loss: 0.3288 - val_categorical_accuracy: 0.9167
# Epoch 461/10000
# 720/720 [==============================] - ETA: 0s - loss: 0.0019 - categorical_accuracy: 1.00 - 0s 76us/step - loss: 0.0022 - categorical_accuracy: 1.0000 - val_loss: 0.2980 - val_categorical_accuracy: 0.9167
# Epoch 462/10000
# 720/720 [==============================] - 0s 85us/step - loss: 0.0027 - categorical_accuracy: 1.0000 - val_loss: 0.3063 - val_categorical_accuracy: 0.9167
# Epoch 463/10000
# 720/720 [==============================] - 0s 84us/step - loss: 0.0020 - categorical_accuracy: 1.0000 - val_loss: 0.3478 - val_categorical_accuracy: 0.9111
# Epoch 464/10000
# 720/720 [==============================] - 0s 72us/step - loss: 0.0019 - categorical_accuracy: 1.0000 - val_loss: 0.3239 - val_categorical_accuracy: 0.9111
# Epoch 465/10000
# 720/720 [==============================] - 0s 83us/step - loss: 0.0024 - categorical_accuracy: 1.0000 - val_loss: 0.3090 - val_categorical_accuracy: 0.9222
# Epoch 466/10000
# 720/720 [==============================] - 0s 86us/step - loss: 0.0022 - categorical_accuracy: 1.0000 - val_loss: 0.3310 - val_categorical_accuracy: 0.9056
# Epoch 467/10000
# 720/720 [==============================] - 0s 85us/step - loss: 0.0023 - categorical_accuracy: 1.0000 - val_loss: 0.3421 - val_categorical_accuracy: 0.9000
# Epoch 468/10000
# 720/720 [==============================] - 0s 84us/step - loss: 0.0024 - categorical_accuracy: 1.0000 - val_loss: 0.3649 - val_categorical_accuracy: 0.9056
# Epoch 469/10000
# 720/720 [==============================] - 0s 66us/step - loss: 0.0026 - categorical_accuracy: 1.0000 - val_loss: 0.3907 - val_categorical_accuracy: 0.9056
# Epoch 470/10000
# 720/720 [==============================] - 0s 84us/step - loss: 0.0022 - categorical_accuracy: 1.0000 - val_loss: 0.3333 - val_categorical_accuracy: 0.9000
# Epoch 471/10000
# 720/720 [==============================] - 0s 59us/step - loss: 0.0018 - categorical_accuracy: 1.0000 - val_loss: 0.3280 - val_categorical_accuracy: 0.9056
# Epoch 472/10000
# 720/720 [==============================] - 0s 74us/step - loss: 0.0020 - categorical_accuracy: 1.0000 - val_loss: 0.3097 - val_categorical_accuracy: 0.9056
# Epoch 473/10000
# 720/720 [==============================] - 0s 68us/step - loss: 0.0020 - categorical_accuracy: 1.0000 - val_loss: 0.3443 - val_categorical_accuracy: 0.9056
# Epoch 474/10000
# 720/720 [==============================] - 0s 84us/step - loss: 0.0025 - categorical_accuracy: 1.0000 - val_loss: 0.3004 - val_categorical_accuracy: 0.9167
# Epoch 475/10000
# 720/720 [==============================] - 0s 86us/step - loss: 0.0020 - categorical_accuracy: 1.0000 - val_loss: 0.3685 - val_categorical_accuracy: 0.9056
# Epoch 476/10000
# 720/720 [==============================] - 0s 99us/step - loss: 0.0028 - categorical_accuracy: 1.0000 - val_loss: 0.3343 - val_categorical_accuracy: 0.9056
# Epoch 477/10000
# 720/720 [==============================] - 0s 79us/step - loss: 0.0027 - categorical_accuracy: 1.0000 - val_loss: 0.3268 - val_categorical_accuracy: 0.9111
# Epoch 478/10000
# 720/720 [==============================] - 0s 111us/step - loss: 0.0028 - categorical_accuracy: 1.0000 - val_loss: 0.3756 - val_categorical_accuracy: 0.9111
# Epoch 479/10000
# 720/720 [==============================] - 0s 75us/step - loss: 0.0021 - categorical_accuracy: 1.0000 - val_loss: 0.3367 - val_categorical_accuracy: 0.9111
# Epoch 480/10000
# 720/720 [==============================] - 0s 73us/step - loss: 0.0021 - categorical_accuracy: 1.0000 - val_loss: 0.3699 - val_categorical_accuracy: 0.9111
# Epoch 481/10000
# 720/720 [==============================] - 0s 94us/step - loss: 0.0022 - categorical_accuracy: 1.0000 - val_loss: 0.3597 - val_categorical_accuracy: 0.9111
# Epoch 482/10000
# 720/720 [==============================] - 0s 73us/step - loss: 0.0020 - categorical_accuracy: 1.0000 - val_loss: 0.3366 - val_categorical_accuracy: 0.9111
# Epoch 483/10000
# 720/720 [==============================] - 0s 76us/step - loss: 0.0023 - categorical_accuracy: 1.0000 - val_loss: 0.3085 - val_categorical_accuracy: 0.9056
# Epoch 484/10000
# 720/720 [==============================] - 0s 85us/step - loss: 0.0020 - categorical_accuracy: 1.0000 - val_loss: 0.3555 - val_categorical_accuracy: 0.9111
# Epoch 485/10000
# 720/720 [==============================] - 0s 84us/step - loss: 0.0017 - categorical_accuracy: 1.0000 - val_loss: 0.3213 - val_categorical_accuracy: 0.9056
# Epoch 486/10000
# 720/720 [==============================] - 0s 77us/step - loss: 0.0023 - categorical_accuracy: 1.0000 - val_loss: 0.3445 - val_categorical_accuracy: 0.9222
# Epoch 487/10000
# 720/720 [==============================] - 0s 81us/step - loss: 0.0028 - categorical_accuracy: 1.0000 - val_loss: 0.3592 - val_categorical_accuracy: 0.9111
# Epoch 488/10000
# 720/720 [==============================] - 0s 82us/step - loss: 0.0020 - categorical_accuracy: 1.0000 - val_loss: 0.3199 - val_categorical_accuracy: 0.9111
# Epoch 489/10000
# 720/720 [==============================] - 0s 67us/step - loss: 0.0017 - categorical_accuracy: 1.0000 - val_loss: 0.3274 - val_categorical_accuracy: 0.9000
# Epoch 490/10000
# 720/720 [==============================] - 0s 75us/step - loss: 0.0017 - categorical_accuracy: 1.0000 - val_loss: 0.3250 - val_categorical_accuracy: 0.9111
# Epoch 491/10000
# 720/720 [==============================] - 0s 71us/step - loss: 0.0020 - categorical_accuracy: 1.0000 - val_loss: 0.3177 - val_categorical_accuracy: 0.9056
# Epoch 492/10000
# 720/720 [==============================] - 0s 71us/step - loss: 0.0026 - categorical_accuracy: 1.0000 - val_loss: 0.2923 - val_categorical_accuracy: 0.9222
# Epoch 493/10000
# 720/720 [==============================] - 0s 85us/step - loss: 0.0019 - categorical_accuracy: 1.0000 - val_loss: 0.3215 - val_categorical_accuracy: 0.9167
# Epoch 494/10000
# 720/720 [==============================] - 0s 80us/step - loss: 0.0021 - categorical_accuracy: 1.0000 - val_loss: 0.3726 - val_categorical_accuracy: 0.9056
# Epoch 495/10000
# 720/720 [==============================] - 0s 76us/step - loss: 0.0018 - categorical_accuracy: 1.0000 - val_loss: 0.3221 - val_categorical_accuracy: 0.9111
# Epoch 496/10000
# 720/720 [==============================] - 0s 74us/step - loss: 0.0018 - categorical_accuracy: 1.0000 - val_loss: 0.3197 - val_categorical_accuracy: 0.9167
# Epoch 497/10000
# 720/720 [==============================] - 0s 62us/step - loss: 0.0020 - categorical_accuracy: 1.0000 - val_loss: 0.3416 - val_categorical_accuracy: 0.9111
# Epoch 498/10000
# 720/720 [==============================] - 0s 63us/step - loss: 0.0017 - categorical_accuracy: 1.0000 - val_loss: 0.3362 - val_categorical_accuracy: 0.9056
# Epoch 499/10000
# 720/720 [==============================] - 0s 58us/step - loss: 0.0020 - categorical_accuracy: 1.0000 - val_loss: 0.3610 - val_categorical_accuracy: 0.9056
# Epoch 500/10000
# 720/720 [==============================] - 0s 56us/step - loss: 0.0020 - categorical_accuracy: 1.0000 - val_loss: 0.3078 - val_categorical_accuracy: 0.9222
# Epoch 501/10000
# 720/720 [==============================] - 0s 57us/step - loss: 0.0021 - categorical_accuracy: 1.0000 - val_loss: 0.3234 - val_categorical_accuracy: 0.9167
# Epoch 502/10000
# 720/720 [==============================] - 0s 77us/step - loss: 0.0015 - categorical_accuracy: 1.0000 - val_loss: 0.3325 - val_categorical_accuracy: 0.9111
# Epoch 503/10000
# 720/720 [==============================] - 0s 70us/step - loss: 0.0020 - categorical_accuracy: 1.0000 - val_loss: 0.3280 - val_categorical_accuracy: 0.9167
# Epoch 504/10000
# 720/720 [==============================] - 0s 67us/step - loss: 0.0021 - categorical_accuracy: 1.0000 - val_loss: 0.3057 - val_categorical_accuracy: 0.9167
# Epoch 505/10000
# 720/720 [==============================] - 0s 66us/step - loss: 0.0021 - categorical_accuracy: 1.0000 - val_loss: 0.3518 - val_categorical_accuracy: 0.9056
# Epoch 506/10000
# 720/720 [==============================] - 0s 63us/step - loss: 0.0016 - categorical_accuracy: 1.0000 - val_loss: 0.3020 - val_categorical_accuracy: 0.9111
# Epoch 507/10000
# 720/720 [==============================] - 0s 85us/step - loss: 0.0020 - categorical_accuracy: 1.0000 - val_loss: 0.3458 - val_categorical_accuracy: 0.9111
# Epoch 508/10000
# 720/720 [==============================] - 0s 79us/step - loss: 0.0015 - categorical_accuracy: 1.0000 - val_loss: 0.3402 - val_categorical_accuracy: 0.9167
# Epoch 509/10000
# 720/720 [==============================] - 0s 76us/step - loss: 0.0017 - categorical_accuracy: 1.0000 - val_loss: 0.3483 - val_categorical_accuracy: 0.9111
# Epoch 510/10000
# 720/720 [==============================] - 0s 69us/step - loss: 0.0015 - categorical_accuracy: 1.0000 - val_loss: 0.3395 - val_categorical_accuracy: 0.9111
# Epoch 511/10000
# 720/720 [==============================] - 0s 57us/step - loss: 0.0018 - categorical_accuracy: 1.0000 - val_loss: 0.3576 - val_categorical_accuracy: 0.9111
# Epoch 512/10000
# 720/720 [==============================] - 0s 55us/step - loss: 0.0016 - categorical_accuracy: 1.0000 - val_loss: 0.3106 - val_categorical_accuracy: 0.9222
# Epoch 513/10000
# 720/720 [==============================] - 0s 57us/step - loss: 0.0022 - categorical_accuracy: 1.0000 - val_loss: 0.3255 - val_categorical_accuracy: 0.9111
# Epoch 514/10000
# 720/720 [==============================] - 0s 69us/step - loss: 0.0029 - categorical_accuracy: 1.0000 - val_loss: 0.3718 - val_categorical_accuracy: 0.9167
# Epoch 515/10000
# 720/720 [==============================] - 0s 70us/step - loss: 0.0021 - categorical_accuracy: 1.0000 - val_loss: 0.3377 - val_categorical_accuracy: 0.9167
# Epoch 516/10000
# 720/720 [==============================] - 0s 55us/step - loss: 0.0019 - categorical_accuracy: 1.0000 - val_loss: 0.3467 - val_categorical_accuracy: 0.9111
# Epoch 517/10000
# 720/720 [==============================] - 0s 65us/step - loss: 0.0014 - categorical_accuracy: 1.0000 - val_loss: 0.3101 - val_categorical_accuracy: 0.9167
# Epoch 518/10000
# 720/720 [==============================] - 0s 62us/step - loss: 0.0016 - categorical_accuracy: 1.0000 - val_loss: 0.3193 - val_categorical_accuracy: 0.9167
# Epoch 519/10000
# 720/720 [==============================] - 0s 90us/step - loss: 0.0018 - categorical_accuracy: 1.0000 - val_loss: 0.3541 - val_categorical_accuracy: 0.9167
# Epoch 00519: early stopping

# %% [markdown]
# # <font color = blue>Training and Validation Graphs</font>

# %%
print("Average Categorical Accuracy Before Early Stopping: "+ str( np.mean(history.history['categorical_accuracy'][-early_patience:])))
print("Average Validation Accuracy Before Early Stopping: "+ str(np.mean(history.history['val_categorical_accuracy'][-early_patience:])))
# Out:
# Average Categorical Accuracy Before Early Stopping: 0.999868055568801
# Average Validation Accuracy Before Early Stopping: 0.9063611139655113

# %%
# %matplotlib inline
df = pd.DataFrame(history.history)
df.plot(subplots=True, grid=True, figsize=(10,15))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ff2a9b4c908>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7ff2a917b438>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7ff2a91435f8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7ff2a1b747b8>],
#       dtype=object)

# %% [markdown]
# # <font color = blue>Testing Accuracy [Software 2.0]</font>

# %%
def decodeLabel(encodedLabel):
    if encodedLabel == 0:
        return "Other"
    elif encodedLabel == 1:
        return "Fizz"
    elif encodedLabel == 2:
        return "Buzz"
    elif encodedLabel == 3:
        return "FizzBuzz"

# %%
from sklearn.metrics import classification_report,confusion_matrix
import matplotlib.pyplot as plt

testData = pd.read_csv('testing.csv')

processedTestData  = encodeData(testData['input'].values)

processedTestLabel = encodeLabel(testData['label'].values)

predictedTestLabel = []

for i,j in zip(processedTestData,processedTestLabel):
    y = model.predict(np.array(i).reshape(-1,10))
    predictedTestLabel.append(decodeLabel(y.argmax()))
    
conf = confusion_matrix(testData['label'].values, predictedTestLabel,labels=("Fizz","Buzz","FizzBuzz","Other"))
print(pd.DataFrame(conf, index=['true:Fizz', 'true:Buzz','true:FizzBuzz','true:Other'], columns=['pred:Fizz', 'pred:Buzz','pred:FizzBuzz','pred:Other']))

plt.imshow(conf, cmap='binary', interpolation='None')
plt.show()

#pd.crosstab(testData['label'].values, predictedTestLabel, rownames, colnames)
# Out:
#                pred:Fizz  pred:Buzz  pred:FizzBuzz  pred:Other
# true:Fizz             26          0              0           1
# true:Buzz              0         14              0           0
# true:FizzBuzz          0          0              6           0
# true:Other             2          1              0          50

# %%
wrong   = 0
right   = 0

testData = pd.read_csv('testing.csv')

processedTestData  = encodeData(testData['input'].values)
processedTestLabel = encodeLabel(testData['label'].values)
predictedTestLabel = []

for i,j in zip(processedTestData,processedTestLabel):
    y = model.predict(np.array(i).reshape(-1,10))
    predictedTestLabel.append(decodeLabel(y.argmax()))
    
    if j.argmax() == y.argmax():
        right = right + 1
    else:
        wrong = wrong + 1

print("Errors: " + str(wrong), " Correct :" + str(right))

print("Testing Accuracy: " + str(right/(right+wrong)*100))

# Please input your UBID and personNumber 
testDataInput = testData['input'].tolist()
testDataLabel = testData['label'].tolist()

testDataInput.insert(0, "UBID")
testDataLabel.insert(0, "XXXXXXXX")

testDataInput.insert(1, "personNumber")
testDataLabel.insert(1, "XXXXXXXX")

predictedTestLabel.insert(0, "")
predictedTestLabel.insert(1, "")

output = {}
output["input"] = testDataInput
output["label"] = testDataLabel

output["predicted_label"] = predictedTestLabel

opdf = pd.DataFrame(output)
opdf.to_csv('output.csv')
# Out:
# Errors: 4  Correct :96
# Testing Accuracy: 96.0
