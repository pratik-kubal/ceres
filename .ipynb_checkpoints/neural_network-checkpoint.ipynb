# %%
from numpy.random import seed
seed(111)
    
from tensorflow import set_random_seed
set_random_seed(125)

from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.callbacks import EarlyStopping, TensorBoard
from keras.utils import np_utils
import keras
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from sklearn.metrics import confusion_matrix

# %%
'''
Linear Regression README:
Modes:
1. Human Observed Dataset
2. GSC
Feature Type:
a. Feature Concat
b. Feature Subs
'''
mode = 1
subMode = 'b'

# %%
def create_setting_one(master_data,pos_data):
    raw_data_temp = pd.concat([pos_data.set_index('img_id_A'),master_data.set_index('img_id')],axis=1,join='inner').reset_index()
    raw_data_feature_concat = pd.concat([raw_data_temp.set_index('img_id_B'),master_data.set_index('img_id')],axis=1,join='inner').reset_index()
    if(np.shape(raw_data_feature_concat)[1] < 25):
        raw_data_feature_concat.drop(['Unnamed: 0'],axis=1,inplace=True)
        num_features = 9 + 1
    else:
        num_features = 512+1
    col_rename = ['img_id_B','img_id_A','target']
    for columns in range(1,len(list(raw_data_feature_concat.columns)[3:])+1):
        if(columns < num_features):
            col_rename.append("fa"+str(columns))
        else:
            col_rename.append("fb"+str(columns - num_features+1))
    raw_data_feature_concat.columns = col_rename
    col_rename.append(col_rename.pop(2))
    temp = col_rename[0]
    col_rename[0] = col_rename[1]
    col_rename[1] = temp
    raw_data_feature_concat = raw_data_feature_concat[col_rename]
    return raw_data_feature_concat

def create_setting_two(raw_data_feature_concat):
    raw_data_feature_subs = pd.concat([raw_data_feature_concat.iloc[:,0:2],raw_data_feature_concat.iloc[:,-1]],axis=1,join='inner').reset_index()
    for columns in range(1,int((len(list(raw_data_feature_concat.columns))-3)/2+1)):
        raw_data_feature_subs['fm'+str(columns)] = abs(raw_data_feature_concat['fa'+str(columns)] - raw_data_feature_concat['fb'+str(columns)])
    col_swap = list(raw_data_feature_subs.columns)[1:]
    col_swap.append(col_swap.pop(2))
    raw_data_feature_subs=raw_data_feature_subs[col_swap]
    return raw_data_feature_subs

def stratifiedSampling(data,test_split,seed):
    train,test = train_test_split(data,test_size = test_split,stratify=data[["target"]],random_state=seed)
    return train,test

def data_selection(mode,subMode):
    # GSC or HOD??
    if(mode == 1):
        hum_obs_master_data = pd.read_csv("../HumanObserved-Dataset/HumanObserved-Dataset/HumanObserved-Features-Data/HumanObserved-Features-Data.csv")
        hum_obs_pos_data = pd.read_csv("../HumanObserved-Dataset/HumanObserved-Dataset/HumanObserved-Features-Data/same_pairs.csv")
        hum_obs_neg_data = pd.read_csv("../HumanObserved-Dataset/HumanObserved-Dataset/HumanObserved-Features-Data/diffn_pairs.csv")
        raw_pos_data = create_setting_one(hum_obs_master_data,hum_obs_pos_data)
        raw_neg_data = create_setting_one(hum_obs_master_data,hum_obs_neg_data.sample(len(raw_pos_data),random_state = 444))
        if(subMode == 'b'):
            raw_pos_data = create_setting_two(raw_pos_data)
            raw_neg_data = create_setting_two(raw_neg_data)
            del hum_obs_master_data,hum_obs_pos_data,hum_obs_neg_data
    elif(mode ==2):
        gsc_master_data = pd.read_csv("../GSC-Dataset/GSC-Dataset/GSC-Features-Data/GSC-Features.csv")
        gsc_pos_data = pd.read_csv("../GSC-Dataset/GSC-Dataset/GSC-Features-Data/same_pairs.csv")
        gsc_neg_data = pd.read_csv("../GSC-Dataset/GSC-Dataset/GSC-Features-Data/diffn_pairs.csv")
                # High Memory -> NEED TO FIX
        raw_pos_data = create_setting_one(gsc_master_data,gsc_pos_data)
        raw_neg_data = create_setting_one(gsc_master_data,gsc_neg_data.sample(len(gsc_pos_data)))
        if(subMode == 'b'):
            raw_pos_data = create_setting_two(raw_pos_data)
            raw_neg_data = create_setting_two(raw_neg_data)
            del gsc_master_data,gsc_pos_data,gsc_neg_data
    '''
    Partition Scheme
    unseenWriter = true
    default = false
    '''
    partScheme = False
    if(partScheme):
        # Unseen Writer partitions
        raw_data_feature_concat_pos[['A','A_imgNo']] = raw_data_feature_concat_pos['img_id_A'].str.extract('(\d\d\d\d)([a-z])', expand=False)
        raw_data_feature_concat_pos[['B','B_imgNo']] = raw_data_feature_concat_pos['img_id_B'].str.extract('(\d\d\d\d)([a-z])', expand=False)
        #raw_data_feature_concat['img_id_A'].str.extract('(?P<writerA>\d\d\d\d)(?P<imageNo>[abcd])', expand=False)
        raw_data_feature_concat_neg[['A','A_imgNo']] = raw_data_feature_concat_neg['img_id_A'].str.extract('(\d\d\d\d)([a-z])', expand=False)
        raw_data_feature_concat_neg[['B','B_imgNo']] = raw_data_feature_concat_neg['img_id_B'].str.extract('(\d\d\d\d)([a-z])', expand=False)
        data = pd.concat([raw_pos_data,raw_neg_data],ignore_index=True)
    else:
        data = pd.concat([raw_pos_data,raw_neg_data],ignore_index=True)
    data = data.iloc[:,2:np.shape(data)[1]]
    
    if(mode == 1):
        train,test = stratifiedSampling(data,0.05,444)
    elif(mode == 2):
        train,test = stratifiedSampling(data,0.1,444)
    
    return train,test

# %%
train,test = data_selection(1,"b")

train = train.sample(frac=1,random_state=444)

# %%
def get_model():
    input_size = len(train.columns)-1
    drop_out = 0.5
    first_dense_layer_nodes  = 256
    second_dense_layer_nodes = 128
    third_dense_layer_nodes = 64
    final_dense_layer_nodes = 2
    model = Sequential()
    
    model.add(Dense(first_dense_layer_nodes, input_dim=input_size))
    model.add(Activation('relu'))
    
    model.add(Dense(second_dense_layer_nodes))
    model.add(Activation('relu'))
    
    # Why dropout?
    # Avoids the model being overfitted for the training data such that it fails to generalize for new 
    # incidences.
    model.add(Dropout(drop_out))
    
    model.add(Dense(second_dense_layer_nodes))
    model.add(Activation('relu'))
    
    model.add(Dense(final_dense_layer_nodes))
    model.add(Activation('softmax'))
    # Why Softmax?
    # Since this is a multi class classification problem, for the last output layer we need to translate the continous signal 
    # into a discrete signal which will give us the classes. The softmax activation converts a vector of arbitary
    # real values into a vector of values in a specific range from which we can get categories.
    # Important thing to note is that the predicted class will belong to only one class, therefore sum of 
    # probabalities sums to one. For Multi label problem we have to use a different activation, perhaps 
    # sigmoid.
    
    model.summary()
    
    # Why use categorical_crossentropy?
    # Here if we have to use crossentropy loss functions we have various choices such as Binary Crossentropy, categorical
    # crossentropy and Sparse Crossentropy. Here we have One-hot Encoded the input therefore we have to use categorical
    # crossentropy.
    # https://jovianlin.io/cat-crossentropy-vs-sparse-cat-crossentropy/
    
    # Commented out to use metrics as categorical_accuracy for categorical data
    #model.compile(optimizer='rmsprop',
    #              loss='categorical_crossentropy',
    #              metrics=['accuracy'])
    #model.compile(loss='categorical_crossentropy', optimizer='rmsprop',metrics=['accuracy'])
    #rmsprop = keras.optimizers.RMSprop(lr=0.01, rho=0.9, epsilon=None, decay=0.0)
    #model.compile(loss='categorical_crossentropy', optimizer=rmsprop,metrics=['accuracy'])
    
    #sgd = keras.optimizers.SGD(lr=0.1, decay=1e-6, momentum=0.9, nesterov=True)
    adadelta = keras.optimizers.Adadelta(lr=0.1, rho=0.95, epsilon=None, decay=0)
    
    model.compile(loss='binary_crossentropy', optimizer=adadelta,metrics=['binary_accuracy'])
    
    return model

model = get_model()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_41 (Dense)             (None, 256)               2560
# _________________________________________________________________
# activation_41 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_42 (Dense)             (None, 128)               32896
# _________________________________________________________________
# activation_42 (Activation)   (None, 128)               0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_43 (Dense)             (None, 128)               16512
# _________________________________________________________________
# activation_43 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_44 (Dense)             (None, 2)                 258
# _________________________________________________________________
# activation_44 (Activation)   (None, 2)                 0
# =================================================================
# Total params: 52,226
# Trainable params: 52,226
# Non-trainable params: 0
# _________________________________________________________________

# %%
def small_model():
    input_size = len(train.columns)-1
    #drop_out = 0.03
    first_dense_layer_nodes  = 1024
    final_dense_layer_nodes = 2
    model = Sequential()
    
    model.add(Dense(first_dense_layer_nodes, input_dim=input_size))
    model.add(Activation('relu'))
    
    # Why dropout?
    # Avoids the model being overfitted for the training data such that it fails to generalize for new 
    # incidences.
    #model.add(Dropout(drop_out))
    
    model.add(Dense(final_dense_layer_nodes))
    model.add(Activation('softmax'))

    
    model.summary()
    
    adadelta = keras.optimizers.Adadelta(lr=0.1, rho=0.95, epsilon=None, decay=0)
    
    model.compile(loss='binary_crossentropy', optimizer=adadelta,metrics=['binary_accuracy'])
    
    return model

model = get_model()

# %%
validation_data_split = 0.1
num_epochs = 10000
model_batch_size = 128
early_patience = 200

earlystopping_cb = EarlyStopping(monitor='binary_accuracy', verbose=1, patience=early_patience, mode='min')

# Process Dataset
model_hist = model.fit(train.iloc[:,0:len(train.columns)-1]
                    , to_categorical(train.iloc[:,len(train.columns)-1:])
                    , validation_split=validation_data_split
                    , epochs=num_epochs
                    , batch_size=model_batch_size
                    , callbacks = [earlystopping_cb]
                   )
# Out:
# Train on 1351 samples, validate on 151 samples
# Epoch 1/10000
# 1351/1351 [==============================] - 1s 969us/step - loss: 0.7193 - binary_accuracy: 0.4981 - val_loss: 0.7011 - val_binary_accuracy: 0.4834
# Epoch 2/10000
# 1351/1351 [==============================] - 0s 84us/step - loss: 0.7071 - binary_accuracy: 0.4907 - val_loss: 0.6978 - val_binary_accuracy: 0.4768
# Epoch 3/10000
# 1351/1351 [==============================] - 0s 81us/step - loss: 0.7048 - binary_accuracy: 0.4833 - val_loss: 0.6969 - val_binary_accuracy: 0.4901
# Epoch 4/10000
# 1351/1351 [==============================] - 0s 97us/step - loss: 0.6986 - binary_accuracy: 0.4959 - val_loss: 0.6958 - val_binary_accuracy: 0.4768
# Epoch 5/10000
# 1351/1351 [==============================] - 0s 84us/step - loss: 0.6975 - binary_accuracy: 0.5100 - val_loss: 0.6955 - val_binary_accuracy: 0.5033
# Epoch 6/10000
# 1351/1351 [==============================] - 0s 87us/step - loss: 0.6933 - binary_accuracy: 0.5218 - val_loss: 0.6958 - val_binary_accuracy: 0.5166
# Epoch 7/10000
# 1351/1351 [==============================] - 0s 99us/step - loss: 0.6900 - binary_accuracy: 0.5285 - val_loss: 0.6950 - val_binary_accuracy: 0.5033
# Epoch 8/10000
# 1351/1351 [==============================] - 0s 107us/step - loss: 0.6954 - binary_accuracy: 0.5255 - val_loss: 0.6947 - val_binary_accuracy: 0.5099
# Epoch 9/10000
# 1351/1351 [==============================] - 0s 100us/step - loss: 0.6980 - binary_accuracy: 0.5137 - val_loss: 0.6940 - val_binary_accuracy: 0.4967
# Epoch 10/10000
# 1351/1351 [==============================] - 0s 89us/step - loss: 0.6938 - binary_accuracy: 0.5189 - val_loss: 0.6944 - val_binary_accuracy: 0.5099
# Epoch 11/10000
# 1351/1351 [==============================] - 0s 113us/step - loss: 0.6911 - binary_accuracy: 0.5241 - val_loss: 0.6947 - val_binary_accuracy: 0.5099
# Epoch 12/10000
# 1351/1351 [==============================] - 0s 122us/step - loss: 0.6950 - binary_accuracy: 0.5167 - val_loss: 0.6943 - val_binary_accuracy: 0.4967
# Epoch 13/10000
# 1351/1351 [==============================] - 0s 94us/step - loss: 0.6931 - binary_accuracy: 0.5122 - val_loss: 0.6938 - val_binary_accuracy: 0.5099
# Epoch 14/10000
# 1351/1351 [==============================] - 0s 110us/step - loss: 0.6909 - binary_accuracy: 0.5181 - val_loss: 0.6934 - val_binary_accuracy: 0.5099
# Epoch 15/10000
# 1351/1351 [==============================] - 0s 80us/step - loss: 0.6913 - binary_accuracy: 0.5374 - val_loss: 0.6940 - val_binary_accuracy: 0.5298
# Epoch 16/10000
# 1351/1351 [==============================] - 0s 85us/step - loss: 0.6900 - binary_accuracy: 0.5337 - val_loss: 0.6934 - val_binary_accuracy: 0.5232
# Epoch 17/10000
# 1351/1351 [==============================] - 0s 95us/step - loss: 0.6901 - binary_accuracy: 0.5300 - val_loss: 0.6930 - val_binary_accuracy: 0.5166
# Epoch 18/10000
# 1351/1351 [==============================] - 0s 97us/step - loss: 0.6918 - binary_accuracy: 0.5366 - val_loss: 0.6925 - val_binary_accuracy: 0.5232
# Epoch 19/10000
# 1351/1351 [==============================] - 0s 115us/step - loss: 0.6880 - binary_accuracy: 0.5366 - val_loss: 0.6929 - val_binary_accuracy: 0.5166
# Epoch 20/10000
# 1351/1351 [==============================] - 0s 126us/step - loss: 0.6877 - binary_accuracy: 0.5440 - val_loss: 0.6927 - val_binary_accuracy: 0.5232
# Epoch 21/10000
# 1351/1351 [==============================] - 0s 101us/step - loss: 0.6901 - binary_accuracy: 0.5241 - val_loss: 0.6926 - val_binary_accuracy: 0.5166
# Epoch 22/10000
# 1351/1351 [==============================] - 0s 103us/step - loss: 0.6896 - binary_accuracy: 0.5381 - val_loss: 0.6931 - val_binary_accuracy: 0.5166
# Epoch 23/10000
# 1351/1351 [==============================] - 0s 87us/step - loss: 0.6871 - binary_accuracy: 0.5315 - val_loss: 0.6937 - val_binary_accuracy: 0.5033
# Epoch 24/10000
# 1351/1351 [==============================] - 0s 84us/step - loss: 0.6850 - binary_accuracy: 0.5403 - val_loss: 0.6936 - val_binary_accuracy: 0.4967
# Epoch 25/10000
# 1351/1351 [==============================] - 0s 129us/step - loss: 0.6852 - binary_accuracy: 0.5507 - val_loss: 0.6937 - val_binary_accuracy: 0.5099
# Epoch 26/10000
# 1351/1351 [==============================] - 0s 87us/step - loss: 0.6843 - binary_accuracy: 0.5603 - val_loss: 0.6942 - val_binary_accuracy: 0.5298
# Epoch 27/10000
# 1351/1351 [==============================] - 0s 75us/step - loss: 0.6831 - binary_accuracy: 0.5596 - val_loss: 0.6934 - val_binary_accuracy: 0.5033
# Epoch 28/10000
# 1351/1351 [==============================] - 0s 87us/step - loss: 0.6871 - binary_accuracy: 0.5329 - val_loss: 0.6926 - val_binary_accuracy: 0.5232
# Epoch 29/10000
# 1351/1351 [==============================] - 0s 101us/step - loss: 0.6865 - binary_accuracy: 0.5403 - val_loss: 0.6925 - val_binary_accuracy: 0.5232
# Epoch 30/10000
# 1351/1351 [==============================] - 0s 94us/step - loss: 0.6886 - binary_accuracy: 0.5359 - val_loss: 0.6930 - val_binary_accuracy: 0.5099
# Epoch 31/10000
# 1351/1351 [==============================] - 0s 78us/step - loss: 0.6852 - binary_accuracy: 0.5655 - val_loss: 0.6927 - val_binary_accuracy: 0.5166
# Epoch 32/10000
# 1351/1351 [==============================] - 0s 90us/step - loss: 0.6825 - binary_accuracy: 0.5707 - val_loss: 0.6925 - val_binary_accuracy: 0.5099
# Epoch 33/10000
# 1351/1351 [==============================] - 0s 144us/step - loss: 0.6873 - binary_accuracy: 0.5322 - val_loss: 0.6925 - val_binary_accuracy: 0.5166
# Epoch 34/10000
# 1351/1351 [==============================] - 0s 114us/step - loss: 0.6817 - binary_accuracy: 0.5714 - val_loss: 0.6920 - val_binary_accuracy: 0.5099
# Epoch 35/10000
# 1351/1351 [==============================] - 0s 112us/step - loss: 0.6853 - binary_accuracy: 0.5625 - val_loss: 0.6917 - val_binary_accuracy: 0.5232
# Epoch 36/10000
# 1351/1351 [==============================] - 0s 96us/step - loss: 0.6860 - binary_accuracy: 0.5455 - val_loss: 0.6918 - val_binary_accuracy: 0.5166
# Epoch 37/10000
# 1351/1351 [==============================] - 0s 90us/step - loss: 0.6834 - binary_accuracy: 0.5418 - val_loss: 0.6919 - val_binary_accuracy: 0.5099
# Epoch 38/10000
# 1351/1351 [==============================] - 0s 112us/step - loss: 0.6867 - binary_accuracy: 0.5455 - val_loss: 0.6920 - val_binary_accuracy: 0.5232
# Epoch 39/10000
# 1351/1351 [==============================] - 0s 103us/step - loss: 0.6850 - binary_accuracy: 0.5603 - val_loss: 0.6920 - val_binary_accuracy: 0.4967
# Epoch 40/10000
# 1351/1351 [==============================] - 0s 114us/step - loss: 0.6846 - binary_accuracy: 0.5655 - val_loss: 0.6923 - val_binary_accuracy: 0.5232
# Epoch 41/10000
# 1351/1351 [==============================] - 0s 116us/step - loss: 0.6839 - binary_accuracy: 0.5507 - val_loss: 0.6923 - val_binary_accuracy: 0.5099
# Epoch 42/10000
# 1351/1351 [==============================] - 0s 118us/step - loss: 0.6860 - binary_accuracy: 0.5440 - val_loss: 0.6922 - val_binary_accuracy: 0.5166
# Epoch 43/10000
# 1351/1351 [==============================] - 0s 87us/step - loss: 0.6838 - binary_accuracy: 0.5588 - val_loss: 0.6924 - val_binary_accuracy: 0.5099
# Epoch 44/10000
# 1351/1351 [==============================] - 0s 93us/step - loss: 0.6840 - binary_accuracy: 0.5455 - val_loss: 0.6923 - val_binary_accuracy: 0.5166
# Epoch 45/10000
# 1351/1351 [==============================] - 0s 79us/step - loss: 0.6854 - binary_accuracy: 0.5588 - val_loss: 0.6923 - val_binary_accuracy: 0.5166
# Epoch 46/10000
# 1351/1351 [==============================] - 0s 76us/step - loss: 0.6806 - binary_accuracy: 0.5618 - val_loss: 0.6923 - val_binary_accuracy: 0.5364
# Epoch 47/10000
# 1351/1351 [==============================] - 0s 86us/step - loss: 0.6806 - binary_accuracy: 0.5707 - val_loss: 0.6928 - val_binary_accuracy: 0.5166
# Epoch 48/10000
# 1351/1351 [==============================] - 0s 75us/step - loss: 0.6806 - binary_accuracy: 0.5692 - val_loss: 0.6929 - val_binary_accuracy: 0.5166
# Epoch 49/10000
# 1351/1351 [==============================] - 0s 91us/step - loss: 0.6791 - binary_accuracy: 0.5796 - val_loss: 0.6930 - val_binary_accuracy: 0.5232
# Epoch 50/10000
# 1351/1351 [==============================] - 0s 82us/step - loss: 0.6801 - binary_accuracy: 0.5670 - val_loss: 0.6935 - val_binary_accuracy: 0.5364
# Epoch 51/10000
# 1351/1351 [==============================] - 0s 88us/step - loss: 0.6794 - binary_accuracy: 0.5707 - val_loss: 0.6933 - val_binary_accuracy: 0.5166
# Epoch 52/10000
# 1351/1351 [==============================] - 0s 96us/step - loss: 0.6780 - binary_accuracy: 0.5662 - val_loss: 0.6933 - val_binary_accuracy: 0.5033
# Epoch 53/10000
# 1351/1351 [==============================] - 0s 81us/step - loss: 0.6805 - binary_accuracy: 0.5736 - val_loss: 0.6933 - val_binary_accuracy: 0.4967
# Epoch 54/10000
# 1351/1351 [==============================] - 0s 83us/step - loss: 0.6772 - binary_accuracy: 0.5692 - val_loss: 0.6938 - val_binary_accuracy: 0.5166
# Epoch 55/10000
# 1351/1351 [==============================] - 0s 79us/step - loss: 0.6791 - binary_accuracy: 0.5699 - val_loss: 0.6943 - val_binary_accuracy: 0.5166
# Epoch 56/10000
# 1351/1351 [==============================] - 0s 90us/step - loss: 0.6774 - binary_accuracy: 0.5766 - val_loss: 0.6936 - val_binary_accuracy: 0.5033
# Epoch 57/10000
# 1351/1351 [==============================] - 0s 98us/step - loss: 0.6824 - binary_accuracy: 0.5581 - val_loss: 0.6936 - val_binary_accuracy: 0.5099
# Epoch 58/10000
# 1351/1351 [==============================] - 0s 89us/step - loss: 0.6840 - binary_accuracy: 0.5366 - val_loss: 0.6936 - val_binary_accuracy: 0.5166
# Epoch 59/10000
# 1351/1351 [==============================] - 0s 84us/step - loss: 0.6756 - binary_accuracy: 0.5707 - val_loss: 0.6933 - val_binary_accuracy: 0.4834
# Epoch 60/10000
# 1351/1351 [==============================] - 0s 70us/step - loss: 0.6800 - binary_accuracy: 0.5670 - val_loss: 0.6938 - val_binary_accuracy: 0.4967
# Epoch 61/10000
# 1351/1351 [==============================] - 0s 91us/step - loss: 0.6754 - binary_accuracy: 0.5818 - val_loss: 0.6941 - val_binary_accuracy: 0.5033
# Epoch 62/10000
# 1351/1351 [==============================] - 0s 67us/step - loss: 0.6792 - binary_accuracy: 0.5537 - val_loss: 0.6945 - val_binary_accuracy: 0.5033
# Epoch 63/10000
# 1351/1351 [==============================] - 0s 78us/step - loss: 0.6748 - binary_accuracy: 0.5959 - val_loss: 0.6946 - val_binary_accuracy: 0.5099
# Epoch 64/10000
# 1351/1351 [==============================] - 0s 83us/step - loss: 0.6764 - binary_accuracy: 0.5662 - val_loss: 0.6951 - val_binary_accuracy: 0.4901
# Epoch 65/10000
# 1351/1351 [==============================] - 0s 102us/step - loss: 0.6744 - binary_accuracy: 0.5811 - val_loss: 0.6951 - val_binary_accuracy: 0.5099
# Epoch 66/10000
# 1351/1351 [==============================] - 0s 111us/step - loss: 0.6765 - binary_accuracy: 0.5803 - val_loss: 0.6946 - val_binary_accuracy: 0.4967
# Epoch 67/10000
# 1351/1351 [==============================] - 0s 89us/step - loss: 0.6734 - binary_accuracy: 0.5892 - val_loss: 0.6946 - val_binary_accuracy: 0.4967
# Epoch 68/10000
# 1351/1351 [==============================] - 0s 113us/step - loss: 0.6746 - binary_accuracy: 0.5766 - val_loss: 0.6941 - val_binary_accuracy: 0.4967
# Epoch 69/10000
# 1351/1351 [==============================] - 0s 114us/step - loss: 0.6755 - binary_accuracy: 0.5811 - val_loss: 0.6941 - val_binary_accuracy: 0.4967
# Epoch 70/10000
# 1351/1351 [==============================] - 0s 106us/step - loss: 0.6773 - binary_accuracy: 0.5714 - val_loss: 0.6940 - val_binary_accuracy: 0.4901
# Epoch 71/10000
# 1351/1351 [==============================] - 0s 133us/step - loss: 0.6755 - binary_accuracy: 0.5811 - val_loss: 0.6944 - val_binary_accuracy: 0.5099
# Epoch 72/10000
# 1351/1351 [==============================] - 0s 87us/step - loss: 0.6762 - binary_accuracy: 0.5840 - val_loss: 0.6934 - val_binary_accuracy: 0.4901
# Epoch 73/10000
# 1351/1351 [==============================] - 0s 98us/step - loss: 0.6709 - binary_accuracy: 0.5870 - val_loss: 0.6939 - val_binary_accuracy: 0.4967
# Epoch 74/10000
# 1351/1351 [==============================] - 0s 90us/step - loss: 0.6753 - binary_accuracy: 0.5662 - val_loss: 0.6938 - val_binary_accuracy: 0.5033
# Epoch 75/10000
# 1351/1351 [==============================] - 0s 90us/step - loss: 0.6752 - binary_accuracy: 0.5818 - val_loss: 0.6940 - val_binary_accuracy: 0.5033
# Epoch 76/10000
# 1351/1351 [==============================] - 0s 84us/step - loss: 0.6720 - binary_accuracy: 0.5699 - val_loss: 0.6943 - val_binary_accuracy: 0.4768
# Epoch 77/10000
# 1351/1351 [==============================] - 0s 98us/step - loss: 0.6751 - binary_accuracy: 0.5907 - val_loss: 0.6942 - val_binary_accuracy: 0.4834
# Epoch 78/10000
# 1351/1351 [==============================] - 0s 84us/step - loss: 0.6737 - binary_accuracy: 0.5870 - val_loss: 0.6942 - val_binary_accuracy: 0.4967
# Epoch 79/10000
# 1351/1351 [==============================] - 0s 89us/step - loss: 0.6764 - binary_accuracy: 0.5744 - val_loss: 0.6940 - val_binary_accuracy: 0.4768
# Epoch 80/10000
# 1351/1351 [==============================] - 0s 80us/step - loss: 0.6721 - binary_accuracy: 0.5862 - val_loss: 0.6944 - val_binary_accuracy: 0.4768
# Epoch 81/10000
# 1351/1351 [==============================] - 0s 84us/step - loss: 0.6801 - binary_accuracy: 0.5603 - val_loss: 0.6943 - val_binary_accuracy: 0.4768
# Epoch 82/10000
# 1351/1351 [==============================] - 0s 75us/step - loss: 0.6756 - binary_accuracy: 0.5811 - val_loss: 0.6946 - val_binary_accuracy: 0.4636
# Epoch 83/10000
# 1351/1351 [==============================] - 0s 86us/step - loss: 0.6713 - binary_accuracy: 0.5914 - val_loss: 0.6944 - val_binary_accuracy: 0.4702
# Epoch 84/10000
# 1351/1351 [==============================] - 0s 85us/step - loss: 0.6734 - binary_accuracy: 0.6003 - val_loss: 0.6940 - val_binary_accuracy: 0.4702
# Epoch 85/10000
# 1351/1351 [==============================] - 0s 102us/step - loss: 0.6707 - binary_accuracy: 0.5922 - val_loss: 0.6943 - val_binary_accuracy: 0.4768
# Epoch 86/10000
# 1351/1351 [==============================] - 0s 84us/step - loss: 0.6753 - binary_accuracy: 0.5818 - val_loss: 0.6953 - val_binary_accuracy: 0.5033
# Epoch 87/10000
# 1351/1351 [==============================] - 0s 84us/step - loss: 0.6738 - binary_accuracy: 0.5855 - val_loss: 0.6951 - val_binary_accuracy: 0.4768
# Epoch 88/10000
# 1351/1351 [==============================] - 0s 78us/step - loss: 0.6720 - binary_accuracy: 0.5670 - val_loss: 0.6950 - val_binary_accuracy: 0.4768
# Epoch 89/10000
# 1351/1351 [==============================] - 0s 92us/step - loss: 0.6686 - binary_accuracy: 0.5833 - val_loss: 0.6949 - val_binary_accuracy: 0.4768
# Epoch 90/10000
# 1351/1351 [==============================] - 0s 95us/step - loss: 0.6728 - binary_accuracy: 0.5774 - val_loss: 0.6948 - val_binary_accuracy: 0.4768
# Epoch 91/10000
# 1351/1351 [==============================] - 0s 103us/step - loss: 0.6718 - binary_accuracy: 0.5781 - val_loss: 0.6951 - val_binary_accuracy: 0.4768
# Epoch 92/10000
# 1351/1351 [==============================] - 0s 92us/step - loss: 0.6736 - binary_accuracy: 0.5907 - val_loss: 0.6950 - val_binary_accuracy: 0.4768
# Epoch 93/10000
# 1351/1351 [==============================] - 0s 82us/step - loss: 0.6710 - binary_accuracy: 0.5914 - val_loss: 0.6950 - val_binary_accuracy: 0.4768
# Epoch 94/10000
# 1351/1351 [==============================] - 0s 83us/step - loss: 0.6739 - binary_accuracy: 0.5818 - val_loss: 0.6948 - val_binary_accuracy: 0.4702
# Epoch 95/10000
# 1351/1351 [==============================] - 0s 94us/step - loss: 0.6660 - binary_accuracy: 0.5870 - val_loss: 0.6954 - val_binary_accuracy: 0.4702
# Epoch 96/10000
# 1351/1351 [==============================] - 0s 87us/step - loss: 0.6748 - binary_accuracy: 0.5862 - val_loss: 0.6950 - val_binary_accuracy: 0.4967
# Epoch 97/10000
# 1351/1351 [==============================] - 0s 98us/step - loss: 0.6712 - binary_accuracy: 0.5781 - val_loss: 0.6941 - val_binary_accuracy: 0.4702
# Epoch 98/10000
# 1351/1351 [==============================] - 0s 91us/step - loss: 0.6675 - binary_accuracy: 0.5840 - val_loss: 0.6946 - val_binary_accuracy: 0.4768
# Epoch 99/10000
# 1351/1351 [==============================] - 0s 92us/step - loss: 0.6722 - binary_accuracy: 0.5825 - val_loss: 0.6953 - val_binary_accuracy: 0.4768
# Epoch 100/10000
# 1351/1351 [==============================] - 0s 95us/step - loss: 0.6692 - binary_accuracy: 0.5899 - val_loss: 0.6948 - val_binary_accuracy: 0.4768
# Epoch 101/10000
# 1351/1351 [==============================] - 0s 100us/step - loss: 0.6698 - binary_accuracy: 0.6025 - val_loss: 0.6952 - val_binary_accuracy: 0.4967
# Epoch 102/10000
# 1351/1351 [==============================] - 0s 71us/step - loss: 0.6639 - binary_accuracy: 0.6018 - val_loss: 0.6954 - val_binary_accuracy: 0.4834
# Epoch 103/10000
# 1351/1351 [==============================] - 0s 75us/step - loss: 0.6740 - binary_accuracy: 0.5774 - val_loss: 0.6959 - val_binary_accuracy: 0.4901
# Epoch 104/10000
# 1351/1351 [==============================] - 0s 82us/step - loss: 0.6701 - binary_accuracy: 0.5759 - val_loss: 0.6956 - val_binary_accuracy: 0.4834
# Epoch 105/10000
# 1351/1351 [==============================] - 0s 78us/step - loss: 0.6683 - binary_accuracy: 0.5914 - val_loss: 0.6957 - val_binary_accuracy: 0.4834
# Epoch 106/10000
# 1351/1351 [==============================] - 0s 80us/step - loss: 0.6674 - binary_accuracy: 0.5699 - val_loss: 0.6956 - val_binary_accuracy: 0.4901
# Epoch 107/10000
# 1351/1351 [==============================] - 0s 63us/step - loss: 0.6676 - binary_accuracy: 0.5914 - val_loss: 0.6964 - val_binary_accuracy: 0.4967
# Epoch 108/10000
# 1351/1351 [==============================] - 0s 92us/step - loss: 0.6698 - binary_accuracy: 0.5885 - val_loss: 0.6967 - val_binary_accuracy: 0.4967
# Epoch 109/10000
# 1351/1351 [==============================] - 0s 80us/step - loss: 0.6734 - binary_accuracy: 0.5892 - val_loss: 0.6962 - val_binary_accuracy: 0.4834
# Epoch 110/10000
# 1351/1351 [==============================] - 0s 89us/step - loss: 0.6646 - binary_accuracy: 0.5973 - val_loss: 0.6965 - val_binary_accuracy: 0.5033
# Epoch 111/10000
# 1351/1351 [==============================] - 0s 74us/step - loss: 0.6638 - binary_accuracy: 0.5922 - val_loss: 0.6969 - val_binary_accuracy: 0.5033
# Epoch 112/10000
# 1351/1351 [==============================] - 0s 90us/step - loss: 0.6627 - binary_accuracy: 0.6195 - val_loss: 0.6960 - val_binary_accuracy: 0.4768
# Epoch 113/10000
# 1351/1351 [==============================] - 0s 85us/step - loss: 0.6661 - binary_accuracy: 0.5936 - val_loss: 0.6966 - val_binary_accuracy: 0.4834
# Epoch 114/10000
# 1351/1351 [==============================] - 0s 110us/step - loss: 0.6657 - binary_accuracy: 0.6099 - val_loss: 0.6971 - val_binary_accuracy: 0.5099
# Epoch 115/10000
# 1351/1351 [==============================] - 0s 91us/step - loss: 0.6620 - binary_accuracy: 0.6136 - val_loss: 0.6979 - val_binary_accuracy: 0.5099
# Epoch 116/10000
# 1351/1351 [==============================] - 0s 114us/step - loss: 0.6627 - binary_accuracy: 0.6144 - val_loss: 0.6980 - val_binary_accuracy: 0.4967
# Epoch 117/10000
# 1351/1351 [==============================] - 0s 89us/step - loss: 0.6661 - binary_accuracy: 0.5922 - val_loss: 0.6973 - val_binary_accuracy: 0.4901
# Epoch 118/10000
# 1351/1351 [==============================] - 0s 79us/step - loss: 0.6684 - binary_accuracy: 0.5922 - val_loss: 0.6972 - val_binary_accuracy: 0.4834
# Epoch 119/10000
# 1351/1351 [==============================] - 0s 78us/step - loss: 0.6668 - binary_accuracy: 0.6070 - val_loss: 0.6975 - val_binary_accuracy: 0.5099
# Epoch 120/10000
# 1351/1351 [==============================] - 0s 84us/step - loss: 0.6677 - binary_accuracy: 0.5870 - val_loss: 0.6980 - val_binary_accuracy: 0.4834
# Epoch 121/10000
# 1351/1351 [==============================] - 0s 110us/step - loss: 0.6632 - binary_accuracy: 0.5892 - val_loss: 0.6982 - val_binary_accuracy: 0.4901
# Epoch 122/10000
# 1351/1351 [==============================] - 0s 110us/step - loss: 0.6663 - binary_accuracy: 0.5929 - val_loss: 0.6972 - val_binary_accuracy: 0.4901
# Epoch 123/10000
# 1351/1351 [==============================] - 0s 99us/step - loss: 0.6655 - binary_accuracy: 0.6003 - val_loss: 0.6967 - val_binary_accuracy: 0.4834
# Epoch 124/10000
# 1351/1351 [==============================] - 0s 95us/step - loss: 0.6666 - binary_accuracy: 0.5936 - val_loss: 0.6969 - val_binary_accuracy: 0.4702
# Epoch 125/10000
# 1351/1351 [==============================] - 0s 74us/step - loss: 0.6672 - binary_accuracy: 0.5796 - val_loss: 0.6969 - val_binary_accuracy: 0.4834
# Epoch 126/10000
# 1351/1351 [==============================] - 0s 93us/step - loss: 0.6652 - binary_accuracy: 0.6114 - val_loss: 0.6975 - val_binary_accuracy: 0.4768
# Epoch 127/10000
# 1351/1351 [==============================] - 0s 81us/step - loss: 0.6650 - binary_accuracy: 0.5959 - val_loss: 0.6987 - val_binary_accuracy: 0.4636
# Epoch 128/10000
# 1351/1351 [==============================] - 0s 112us/step - loss: 0.6632 - binary_accuracy: 0.6107 - val_loss: 0.6988 - val_binary_accuracy: 0.4834
# Epoch 129/10000
# 1351/1351 [==============================] - 0s 99us/step - loss: 0.6610 - binary_accuracy: 0.6181 - val_loss: 0.6981 - val_binary_accuracy: 0.4768
# Epoch 130/10000
# 1351/1351 [==============================] - 0s 83us/step - loss: 0.6620 - binary_accuracy: 0.6099 - val_loss: 0.6990 - val_binary_accuracy: 0.4834
# Epoch 131/10000
# 1351/1351 [==============================] - 0s 102us/step - loss: 0.6620 - binary_accuracy: 0.5966 - val_loss: 0.6989 - val_binary_accuracy: 0.4967
# Epoch 132/10000
# 1351/1351 [==============================] - 0s 82us/step - loss: 0.6607 - binary_accuracy: 0.6129 - val_loss: 0.6995 - val_binary_accuracy: 0.4834
# Epoch 133/10000
# 1351/1351 [==============================] - 0s 89us/step - loss: 0.6592 - binary_accuracy: 0.6158 - val_loss: 0.6997 - val_binary_accuracy: 0.4768
# Epoch 134/10000
# 1351/1351 [==============================] - 0s 106us/step - loss: 0.6587 - binary_accuracy: 0.6144 - val_loss: 0.6996 - val_binary_accuracy: 0.4901
# Epoch 135/10000
# 1351/1351 [==============================] - 0s 78us/step - loss: 0.6680 - binary_accuracy: 0.5981 - val_loss: 0.7000 - val_binary_accuracy: 0.4901
# Epoch 136/10000
# 1351/1351 [==============================] - 0s 95us/step - loss: 0.6584 - binary_accuracy: 0.6084 - val_loss: 0.7006 - val_binary_accuracy: 0.4768
# Epoch 137/10000
# 1351/1351 [==============================] - 0s 99us/step - loss: 0.6596 - binary_accuracy: 0.6099 - val_loss: 0.7006 - val_binary_accuracy: 0.4901
# Epoch 138/10000
# 1351/1351 [==============================] - 0s 100us/step - loss: 0.6589 - binary_accuracy: 0.5966 - val_loss: 0.7023 - val_binary_accuracy: 0.4901
# Epoch 139/10000
# 1351/1351 [==============================] - 0s 111us/step - loss: 0.6633 - binary_accuracy: 0.6070 - val_loss: 0.7013 - val_binary_accuracy: 0.4834
# Epoch 140/10000
# 1351/1351 [==============================] - 0s 111us/step - loss: 0.6614 - binary_accuracy: 0.6055 - val_loss: 0.7013 - val_binary_accuracy: 0.4834
# Epoch 141/10000
# 1351/1351 [==============================] - 0s 97us/step - loss: 0.6585 - binary_accuracy: 0.6114 - val_loss: 0.7010 - val_binary_accuracy: 0.4834
# Epoch 142/10000
# 1351/1351 [==============================] - 0s 116us/step - loss: 0.6553 - binary_accuracy: 0.6181 - val_loss: 0.7007 - val_binary_accuracy: 0.4702
# Epoch 143/10000
# 1351/1351 [==============================] - 0s 125us/step - loss: 0.6583 - binary_accuracy: 0.6010 - val_loss: 0.7013 - val_binary_accuracy: 0.4636
# Epoch 144/10000
# 1351/1351 [==============================] - 0s 108us/step - loss: 0.6603 - binary_accuracy: 0.6062 - val_loss: 0.7021 - val_binary_accuracy: 0.4702
# Epoch 145/10000
# 1351/1351 [==============================] - 0s 95us/step - loss: 0.6610 - binary_accuracy: 0.6055 - val_loss: 0.7020 - val_binary_accuracy: 0.4702
# Epoch 146/10000
# 1351/1351 [==============================] - 0s 91us/step - loss: 0.6575 - binary_accuracy: 0.6292 - val_loss: 0.7020 - val_binary_accuracy: 0.4702
# Epoch 147/10000
# 1351/1351 [==============================] - 0s 79us/step - loss: 0.6577 - binary_accuracy: 0.5944 - val_loss: 0.7030 - val_binary_accuracy: 0.4768
# Epoch 148/10000
# 1351/1351 [==============================] - 0s 81us/step - loss: 0.6581 - binary_accuracy: 0.6077 - val_loss: 0.7037 - val_binary_accuracy: 0.4702
# Epoch 149/10000
# 1351/1351 [==============================] - 0s 72us/step - loss: 0.6601 - binary_accuracy: 0.6040 - val_loss: 0.7027 - val_binary_accuracy: 0.4702
# Epoch 150/10000
# 1351/1351 [==============================] - 0s 93us/step - loss: 0.6599 - binary_accuracy: 0.5951 - val_loss: 0.7029 - val_binary_accuracy: 0.4702
# Epoch 151/10000
# 1351/1351 [==============================] - 0s 85us/step - loss: 0.6574 - binary_accuracy: 0.6262 - val_loss: 0.7024 - val_binary_accuracy: 0.4702
# Epoch 152/10000
# 1351/1351 [==============================] - 0s 81us/step - loss: 0.6573 - binary_accuracy: 0.6210 - val_loss: 0.7015 - val_binary_accuracy: 0.4768
# Epoch 153/10000
# 1351/1351 [==============================] - 0s 76us/step - loss: 0.6562 - binary_accuracy: 0.6025 - val_loss: 0.7027 - val_binary_accuracy: 0.4570
# Epoch 154/10000
# 1351/1351 [==============================] - 0s 71us/step - loss: 0.6523 - binary_accuracy: 0.6299 - val_loss: 0.7044 - val_binary_accuracy: 0.4702
# Epoch 155/10000
# 1351/1351 [==============================] - 0s 88us/step - loss: 0.6511 - binary_accuracy: 0.6173 - val_loss: 0.7051 - val_binary_accuracy: 0.4702
# Epoch 156/10000
# 1351/1351 [==============================] - 0s 81us/step - loss: 0.6589 - binary_accuracy: 0.6055 - val_loss: 0.7035 - val_binary_accuracy: 0.4702
# Epoch 157/10000
# 1351/1351 [==============================] - 0s 78us/step - loss: 0.6580 - binary_accuracy: 0.6084 - val_loss: 0.7039 - val_binary_accuracy: 0.4702
# Epoch 158/10000
# 1351/1351 [==============================] - 0s 91us/step - loss: 0.6580 - binary_accuracy: 0.5951 - val_loss: 0.7030 - val_binary_accuracy: 0.4967
# Epoch 159/10000
# 1351/1351 [==============================] - 0s 92us/step - loss: 0.6586 - binary_accuracy: 0.5988 - val_loss: 0.7035 - val_binary_accuracy: 0.4768
# Epoch 160/10000
# 1351/1351 [==============================] - 0s 93us/step - loss: 0.6542 - binary_accuracy: 0.6225 - val_loss: 0.7032 - val_binary_accuracy: 0.4768
# Epoch 161/10000
# 1351/1351 [==============================] - 0s 91us/step - loss: 0.6577 - binary_accuracy: 0.5944 - val_loss: 0.7027 - val_binary_accuracy: 0.4768
# Epoch 162/10000
# 1351/1351 [==============================] - 0s 87us/step - loss: 0.6570 - binary_accuracy: 0.6047 - val_loss: 0.7038 - val_binary_accuracy: 0.4768
# Epoch 163/10000
# 1351/1351 [==============================] - 0s 83us/step - loss: 0.6482 - binary_accuracy: 0.6292 - val_loss: 0.7055 - val_binary_accuracy: 0.4768
# Epoch 164/10000
# 1351/1351 [==============================] - 0s 77us/step - loss: 0.6501 - binary_accuracy: 0.6292 - val_loss: 0.7060 - val_binary_accuracy: 0.4702
# Epoch 165/10000
# 1351/1351 [==============================] - 0s 91us/step - loss: 0.6575 - binary_accuracy: 0.6144 - val_loss: 0.7048 - val_binary_accuracy: 0.4768
# Epoch 166/10000
# 1351/1351 [==============================] - 0s 86us/step - loss: 0.6527 - binary_accuracy: 0.6166 - val_loss: 0.7040 - val_binary_accuracy: 0.4834
# Epoch 167/10000
# 1351/1351 [==============================] - 0s 72us/step - loss: 0.6550 - binary_accuracy: 0.6070 - val_loss: 0.7044 - val_binary_accuracy: 0.4702
# Epoch 168/10000
# 1351/1351 [==============================] - 0s 93us/step - loss: 0.6555 - binary_accuracy: 0.6047 - val_loss: 0.7044 - val_binary_accuracy: 0.4834
# Epoch 169/10000
# 1351/1351 [==============================] - 0s 80us/step - loss: 0.6514 - binary_accuracy: 0.6299 - val_loss: 0.7048 - val_binary_accuracy: 0.4702
# Epoch 170/10000
# 1351/1351 [==============================] - 0s 73us/step - loss: 0.6543 - binary_accuracy: 0.6277 - val_loss: 0.7049 - val_binary_accuracy: 0.4702
# Epoch 171/10000
# 1351/1351 [==============================] - 0s 93us/step - loss: 0.6567 - binary_accuracy: 0.6033 - val_loss: 0.7042 - val_binary_accuracy: 0.4702
# Epoch 172/10000
# 1351/1351 [==============================] - 0s 101us/step - loss: 0.6523 - binary_accuracy: 0.6144 - val_loss: 0.7059 - val_binary_accuracy: 0.4834
# Epoch 173/10000
# 1351/1351 [==============================] - 0s 100us/step - loss: 0.6520 - binary_accuracy: 0.6114 - val_loss: 0.7064 - val_binary_accuracy: 0.4768
# Epoch 174/10000
# 1351/1351 [==============================] - 0s 78us/step - loss: 0.6518 - binary_accuracy: 0.6395 - val_loss: 0.7064 - val_binary_accuracy: 0.4768
# Epoch 175/10000
# 1351/1351 [==============================] - 0s 94us/step - loss: 0.6448 - binary_accuracy: 0.6351 - val_loss: 0.7065 - val_binary_accuracy: 0.4834
# Epoch 176/10000
# 1351/1351 [==============================] - 0s 108us/step - loss: 0.6570 - binary_accuracy: 0.6151 - val_loss: 0.7056 - val_binary_accuracy: 0.4834
# Epoch 177/10000
# 1351/1351 [==============================] - 0s 86us/step - loss: 0.6514 - binary_accuracy: 0.6240 - val_loss: 0.7058 - val_binary_accuracy: 0.4768
# Epoch 178/10000
# 1351/1351 [==============================] - 0s 105us/step - loss: 0.6510 - binary_accuracy: 0.6136 - val_loss: 0.7065 - val_binary_accuracy: 0.4834
# Epoch 179/10000
# 1351/1351 [==============================] - 0s 104us/step - loss: 0.6612 - binary_accuracy: 0.6010 - val_loss: 0.7053 - val_binary_accuracy: 0.4768
# Epoch 180/10000
# 1351/1351 [==============================] - 0s 120us/step - loss: 0.6502 - binary_accuracy: 0.6166 - val_loss: 0.7041 - val_binary_accuracy: 0.4768
# Epoch 181/10000
# 1351/1351 [==============================] - 0s 89us/step - loss: 0.6529 - binary_accuracy: 0.6203 - val_loss: 0.7046 - val_binary_accuracy: 0.4768
# Epoch 182/10000
# 1351/1351 [==============================] - 0s 70us/step - loss: 0.6467 - binary_accuracy: 0.6314 - val_loss: 0.7061 - val_binary_accuracy: 0.4834
# Epoch 183/10000
# 1351/1351 [==============================] - 0s 81us/step - loss: 0.6523 - binary_accuracy: 0.6121 - val_loss: 0.7068 - val_binary_accuracy: 0.4901
# Epoch 184/10000
# 1351/1351 [==============================] - 0s 82us/step - loss: 0.6546 - binary_accuracy: 0.6099 - val_loss: 0.7067 - val_binary_accuracy: 0.4967
# Epoch 185/10000
# 1351/1351 [==============================] - 0s 84us/step - loss: 0.6505 - binary_accuracy: 0.6225 - val_loss: 0.7073 - val_binary_accuracy: 0.4768
# Epoch 186/10000
# 1351/1351 [==============================] - 0s 93us/step - loss: 0.6510 - binary_accuracy: 0.6084 - val_loss: 0.7077 - val_binary_accuracy: 0.4768
# Epoch 187/10000
# 1351/1351 [==============================] - 0s 100us/step - loss: 0.6520 - binary_accuracy: 0.6173 - val_loss: 0.7061 - val_binary_accuracy: 0.4768
# Epoch 188/10000
# 1351/1351 [==============================] - 0s 116us/step - loss: 0.6462 - binary_accuracy: 0.6151 - val_loss: 0.7068 - val_binary_accuracy: 0.4834
# Epoch 189/10000
# 1351/1351 [==============================] - 0s 103us/step - loss: 0.6494 - binary_accuracy: 0.6299 - val_loss: 0.7066 - val_binary_accuracy: 0.4834
# Epoch 190/10000
# 1351/1351 [==============================] - 0s 88us/step - loss: 0.6421 - binary_accuracy: 0.6462 - val_loss: 0.7072 - val_binary_accuracy: 0.4768
# Epoch 191/10000
# 1351/1351 [==============================] - 0s 83us/step - loss: 0.6517 - binary_accuracy: 0.6144 - val_loss: 0.7065 - val_binary_accuracy: 0.4768
# Epoch 192/10000
# 1351/1351 [==============================] - 0s 110us/step - loss: 0.6495 - binary_accuracy: 0.6173 - val_loss: 0.7075 - val_binary_accuracy: 0.4768
# Epoch 193/10000
# 1351/1351 [==============================] - 0s 130us/step - loss: 0.6489 - binary_accuracy: 0.6358 - val_loss: 0.7087 - val_binary_accuracy: 0.4702
# Epoch 194/10000
# 1351/1351 [==============================] - 0s 114us/step - loss: 0.6453 - binary_accuracy: 0.6299 - val_loss: 0.7098 - val_binary_accuracy: 0.4768
# Epoch 195/10000
# 1351/1351 [==============================] - 0s 94us/step - loss: 0.6501 - binary_accuracy: 0.6121 - val_loss: 0.7087 - val_binary_accuracy: 0.4702
# Epoch 196/10000
# 1351/1351 [==============================] - 0s 89us/step - loss: 0.6514 - binary_accuracy: 0.6203 - val_loss: 0.7073 - val_binary_accuracy: 0.4702
# Epoch 197/10000
# 1351/1351 [==============================] - 0s 83us/step - loss: 0.6400 - binary_accuracy: 0.6277 - val_loss: 0.7074 - val_binary_accuracy: 0.4834
# Epoch 198/10000
# 1351/1351 [==============================] - 0s 109us/step - loss: 0.6475 - binary_accuracy: 0.6432 - val_loss: 0.7079 - val_binary_accuracy: 0.4768
# Epoch 199/10000
# 1351/1351 [==============================] - 0s 90us/step - loss: 0.6381 - binary_accuracy: 0.6425 - val_loss: 0.7085 - val_binary_accuracy: 0.4702
# Epoch 200/10000
# 1351/1351 [==============================] - 0s 87us/step - loss: 0.6467 - binary_accuracy: 0.6173 - val_loss: 0.7075 - val_binary_accuracy: 0.4901
# Epoch 201/10000
# 1351/1351 [==============================] - 0s 97us/step - loss: 0.6369 - binary_accuracy: 0.6521 - val_loss: 0.7089 - val_binary_accuracy: 0.4834
# Epoch 202/10000
# 1351/1351 [==============================] - 0s 92us/step - loss: 0.6440 - binary_accuracy: 0.6329 - val_loss: 0.7077 - val_binary_accuracy: 0.4768
# Epoch 203/10000
# 1351/1351 [==============================] - 0s 86us/step - loss: 0.6373 - binary_accuracy: 0.6366 - val_loss: 0.7075 - val_binary_accuracy: 0.4901
# Epoch 00203: early stopping

# %%
print("Average Categorical Accuracy Before Early Stopping: "+ str( np.mean(model_hist.history['binary_accuracy'][-early_patience:])))
print("Average Validation Accuracy Before Early Stopping: "+ str(np.mean(model_hist.history['val_binary_accuracy'][-early_patience:])))
# Out:
# Average Categorical Accuracy Before Early Stopping: 0.5864951885864965
# Average Validation Accuracy Before Early Stopping: 0.4909933767502277

# %%
# %matplotlib inline
df = pd.DataFrame(model_hist.history)
df.plot(subplots=True, grid=True, figsize=(10,15))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fd8a227fdd8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fd8a14bdac8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fd8a0b23438>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fd8a0ac95f8>],
#       dtype=object)

# %%
y = model.predict(np.array(test.iloc[:,0:len(test.columns)-1]))
predicted = np.around(y,0)

# %%
confusion_matrix(to_categorical(test['target'].values).argmax(axis=1), predicted.argmax(axis=1))
# Out:
# array([[17, 23],
#        [16, 24]])
